# %%
from mpl_toolkits import mplot3d

# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import pandas as pd

# %%
#triv version of openmp program polus
x = np.array([1, 2, 4, 8, 16, 32, 64, 128,
              1, 2, 4, 8, 16, 32, 64, 128,
              1, 2, 4, 8, 16, 32, 64, 128,
              1, 2, 4, 8, 16, 32, 64, 128,
              1, 2, 4, 8, 16, 32, 64, 128,
             ])

y = np.array([4000, 4000, 4000, 4000, 4000, 4000, 4000, 4000,
             2000, 2000, 2000, 2000, 2000, 2000, 2000, 2000,
             400, 400, 400, 400, 400, 400, 400, 400,
             120, 120, 120, 120, 120, 120, 120, 120,
             40, 40, 40, 40, 40, 40, 40, 40
             ])

z = np.array([0.09244039999999999, 0.04656375, 0.028892949999999994, 0.02629325, 0.017357699999999997, 0.01206755, 0.01616835, 0.043521649999999995, 
              0.01930595, 0.0096685, 0.006368400000000001, 0.005271100000000001, 0.00359875, 0.0024044, 0.0036656999999999996, 0.013509949999999998,
              0.0007498, 0.0003944500000000001, 0.00023109999999999998, 0.00022055, 0.000249, 0.0003627, 0.0013566499999999998, 0.009428899999999999, 
              6.855e-05, 6.900000000000002e-05, 6.915000000000001e-05, 7.090000000000002e-05, 7.245000000000001e-05, 0.00015394999999999997, 0.00034885000000000005, 0.00040689999999999997, 
              9.950000000000001e-06, 1.03e-05, 1e-05, 1.02e-05, 1.0399999999999999e-05, 2.3049999999999998e-05, 4.835e-05, 7.525000000000001e-05
             ])

# %%
#triv version of openmp program bluegene
x = np.array([1, 2, 4,
              1, 2, 4,
              1, 2, 4,
              1, 2, 4,
              1, 2, 4,
             ])

y = np.array([4000, 4000, 4000,
             2000, 2000, 2000,
             400, 400, 400,
             120, 120, 120,
             40, 40, 40,
             ])

z = np.array([2.039493, 1.020675, 0.510375,
              0.508438, 0.253522, 0.127227,
              0.019674, 0.010019, 0.006130,
              0.006823, 0.006823, 0.006823,
              0.006771, 0.006771, 0.006771
             ])

# %%
#polus
x = np.array([1, 2, 4, 8, 16, 32, 64, 128,
              1, 2, 4, 8, 16, 32, 64, 128,
              1, 2, 4, 8, 16, 32, 64, 128,
              1, 2, 4, 8, 16, 32, 64, 128,
              1, 2, 4, 8, 16, 32, 64, 128,
             ])

y = np.array([4000, 4000, 4000, 4000, 4000, 4000, 4000, 4000,
             2000, 2000, 2000, 2000, 2000, 2000, 2000, 2000,
             400, 400, 400, 400, 400, 400, 400, 400,
             120, 120, 120, 120, 120, 120, 120, 120,
             40, 40, 40, 40, 40, 40, 40, 40
             ])

z = np.array([0.062276599999999994, 0.03318889999999999, 0.0215936, 0.019105499999999997, 0.0121932, 0.0101635, 0.0126865, 0.030118299999999997,
              0.0157055, 0.007936299999999999, 0.006081600000000001, 0.0048457, 0.003354, 0.0028464, 0.0041978, 0.010962399999999999,
              0.0006260999999999999, 0.00038810000000000006, 0.0003234, 0.00032199999999999997, 0.00037219999999999994, 0.0006062, 0.0014956000000000001, 0.0095328,
              6.09e-05, 5.8299999999999994e-05, 5.930000000000001e-05, 5.88e-05, 7.26e-05, 0.0001583, 0.00040530000000000004, 0.00038629999999999996,
              9.800000000000001e-06, 1.01e-05, 9.9e-06, 1.02e-05, 9.9e-06, 2.4400000000000004e-05, 5.72e-05, 6.939999999999999e-05
             ])

# %%
#bluegen
x = np.array([1, 2, 4,
              1, 2, 4,
              1, 2, 4,
              1, 2, 4,
              1, 2, 4,
             ])

y = np.array([4000, 4000, 4000,
             2000, 2000, 2000,
             400, 400, 400,
             120, 120, 120,
             40, 40, 40,
             ])

z = np.array([1.218236, 0.598536, 0.301901,
              0.302241, 0.152130, 0.076187,
              0.013102, 0.006137, 0.002971,
              0.006479, 0.006479, 0.006479,
              0.005653, 0.005653, 0.005653
             ])

# %%
#3.1 GHz AMD Ryzen 4600U gcc-9 -O0
x = np.array([1, 2, 4,
              1, 2, 4,
              1, 2, 4,
              1, 2, 4,
              1, 2, 4,
             ])

y = np.array([4000, 4000, 4000,
             2000, 2000, 2000,
             400, 400, 400,
             120, 120, 120,
             40, 40, 40
             ])

z = np.array([0.172803, 0.08908880000000001, 0.0845516,
              0.043300399999999996, 0.0228455, 0.021649400000000003,
              0.0018628, 0.001381, 0.0011478999999999999,
              0.0001816, 0.00017490000000000002, 0.00016309999999999998,
              3.19e-05, 4.99e-05, 4.08e-05
             ])

# %%
#3.1 GHz AMD Ryzen 4600U gcc-9 -O1
x = np.array([1, 2, 4,
              1, 2, 4,
              1, 2, 4,
              1, 2, 4,
              1, 2, 4,
             ])

y = np.array([4000, 4000, 4000,
             2000, 2000, 2000,
             400, 400, 400,
             120, 120, 120,
             40, 40, 40
             ])

z = np.array([0.0745251, 0.0418873, 0.030672299999999996,
              0.018074600000000003, 0.0097695, 0.0070158,
              0.0007418000000000001, 0.0006744000000000001, 0.0004717000000000001,
              7.62e-05, 8.42e-05, 7.47e-05,
              1.65e-05, 2.3599999999999998e-05, 2.2e-05
             ])

# %%
#3.1 GHz AMD Ryzen 4600U gcc-9 -O2
x = np.array([1, 2, 4,
              1, 2, 4,
              1, 2, 4,
              1, 2, 4,
              1, 2, 4,
             ])

y = np.array([4000, 4000, 4000,
             2000, 2000, 2000,
             400, 400, 400,
             120, 120, 120,
             40, 40, 40
             ])

z = np.array([0.05037400000000001, 0.028756299999999995, 0.022995800000000004,
              0.0112207, 0.0072958, 0.005546199999999999,
              0.00046359999999999994, 0.000479, 0.0004216,
              5.8e-05, 6.1000000000000005e-05, 5.850000000000001e-05,
              1.92e-05, 1.9299999999999998e-05, 1.76e-05
             ])

# %%
#3.1 GHz AMD Ryzen 4600U gcc-9 -O3
x = np.array([1, 2, 4,
              1, 2, 4,
              1, 2, 4,
              1, 2, 4,
              1, 2, 4,
             ])

y = np.array([4000, 4000, 4000,
             2000, 2000, 2000,
             400, 400, 400,
             120, 120, 120,
             40, 40, 40
             ])

z = np.array([0.0458274, 0.0280758, 0.024083799999999995,
              0.0102336, 0.006275299999999999, 0.0053473,
              0.0004267, 0.00044860000000000006, 0.0003099,
              5.12e-05, 4.61e-05, 4.7199999999999995e-05,
              1.53e-05, 1.52e-05, 1.7700000000000003e-05
             ])

# %%
#START
x = np.array([40, 120, 400, 2000, 4000])
y_0 = np.array([3.1549999999999994e-05, 0.00016450000000000004, 0.0016922999999999997, 0.04174310000000001, 0.1717962])
y_1 = np.array([2.0050000000000003e-05, 7.775e-05, 0.0006805499999999999, 0.017478550000000002, 0.07318944999999999])
y_2 = np.array([1.6150000000000003e-05, 5.22e-05, 0.00042785, 0.01128855, 0.050826649999999994])
y_3 = np.array([1.855e-05, 4.645e-05, 0.00043900000000000005, 0.0099426, 0.04660195])

# %%
#UPT CODE
x = np.array([40, 120, 400, 2000, 4000])
y_0 = np.array([0.1551128, 0.0383706, 0.0016419, 0.0001816, 1.6899999999999997e-05])
y_1 = np.array([0.048116, 0.0177145, 0.0006726, 7.23e-05, 7.2999999999999996e-06])
y_2 = np.array([0.0474217, 0.0124266, 0.00040879999999999996, 5.1000000000000006e-05, 4.4e-06])
y_3 = np.array([0.0460045, 0.010731399999999999, 0.0003526, 5.2300000000000004e-05, 3.2999999999999997e-06])
y_0 = y_0[::-1]
y_1 = y_1[::-1]
y_2 = y_2[::-1]
y_3 = y_3[::-1]

# %%
fig, ax = plt.subplots(figsize=(15,15))
plt.title('2.3 GHz Intel Core i5 7360U (UPDATE)')
ax.set_xlabel('Dataset size')
ax.set_ylabel('Execute time')
ax.plot(x, y_0, label='-O0')
ax.plot(x, y_1, label='-O1')
ax.plot(x, y_2, label='-O2')
ax.plot(x, y_3, label='-O3')

legend = ax.legend(loc='upper left', shadow=True, fontsize='x-large')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(15,15))
ax = plt.axes(projection='3d')
plt.title('Polus simple omp')
ax.set_xlabel('Count of threads')
ax.set_ylabel('Dataset size')
ax.set_zlabel('Execute time')
ax.plot_trisurf(x, y, z, cmap='viridis', edgecolor='none')

# %%
df = pd.DataFrame(data=[x.astype(int), y.astype(int), z]).transpose()
df.columns = ('Count of threads', 'Dataset size', 'Execute time')
df = df.sort_values(by=['Count of threads', 'Dataset size'])
df.to_csv('./triv_version_of_openmp_program_polus.csv', index=False, float_format='%.4f')
# Out:
#     Count of threads  Dataset size  Execute time
# 32               1.0          40.0      0.000010
# 24               1.0         120.0      0.000069
# 16               1.0         400.0      0.000750
# 8                1.0        2000.0      0.019306
# 0                1.0        4000.0      0.092440
# 33               2.0          40.0      0.000010
# 25               2.0         120.0      0.000069
# 17               2.0         400.0      0.000394
# 9                2.0        2000.0      0.009669
# 1                2.0        4000.0      0.046564
# 34               4.0          40.0      0.000010
# 26               4.0         120.0      0.000069
# 18               4.0         400.0      0.000231
# 10               4.0        2000.0      0.006368
# 2                4.0        4000.0      0.028893
# 35               8.0          40.0      0.000010
# 27               8.0         120.0      0.000071
# 19               8.0         400.0      0.000221
# ...
